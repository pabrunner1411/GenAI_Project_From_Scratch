# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/GenAI/')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.environ["HUGGINGFACEHUB_API_TOKEN"] = # add private token here

# %%
from builder import ImagePromptBuilder

# %%
mock_json_dir = '/content/drive/MyDrive/GenAI/mock.json'

# %%
builder = ImagePromptBuilder()
image_prompt = builder.generate_image_prompt(mock_json_dir)
# Out:
# llm_prompt:
# You are an expert prompt engineer for AI image generation. Your task is to create a single, coherent, descriptive prompt for a text-to-image diffusion model.
#
# Based on the following character information, create a detailed image generation prompt.
# CHARACTER INFORMATION:
# Character Name: Alice
#  Visual Traits: golden hair, blue eyes, pale skin, blue dress, white apron
#  Personality: curious, brave, imaginative, polite
#  Description: A young girl with golden hair and curious blue eyes. She wears a simple blue dress and white apron.
#  Book aesthetic:
# Mood: whimsical and mysterious
#  Settings: Wonderland, surreal fantasy world
#
# Image Artistic style: digital illustration, storybook art style, warm color palette, soft lighting, painterly texture, detailed background, expressive brushwork, atmospheric, cohesive composition
#
# INSTRUCTIONS:
# - Create ONLY the image prompt text, nothing else
# - Do not include code, explanations, or extra text
# ...

# %%
image_prompt
# Out:
# "Alice, a young girl with golden hair, curious blue eyes, pale skin, blue dress, and white apron, stands in a surreal fantasy world. She wears a simple blue dress and white apron. Her hair sways gently as she looks up at the sky, her eyes sparkling with curiosity. The atmosphere is warm and inviting, with soft lighting and a painterly texture. The background is detailed and atmospheric, filled with swirling clouds and fantastical creatures. Alice's expression is expressive, conveying her bravery and imagination. The overall composition is cohesive, drawing the viewer into the magical world of Wonderland."
