# %% [markdown]
# ## Example Showcase

# %%
from utils import ImagePromptBuilder, get_hf_client

# %%
client = get_hf_client()
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# LLM model mistralai/Mistral-7B-Instruct-v0.1 activated!

# %%
builder = ImagePromptBuilder(client)

# %%
image_prompt = builder.generate_image_prompt("Lucy")
# Out:
# llm_prompt:
# You are an expert prompt engineer for AI image generation. Your task is to create a single, coherent, descriptive prompt for a text-to-image diffusion model.
#
# Based on the following character information, book atmosphere, and artistic style, create a detailed image generation prompt.
#
# CHARACTER AND BOOK INFORMATION:
# Character Name: Lucy
# Physical Appearance: She has a face she studies in the glass and describes herself as having a tough nut to crack when someone tries to read her expression.
# Personality Traits: Loving, Secretive, Playful, Passionate
# Signature Pose or Expression: Blushing as she writes about love
# Vibe and Mood: Romantic, excited, and confessional
#
# Book Atmosphere:
# Overall Mood Keywords: gothic, dread, uncanny, suspense, nocturnal
# Visual Palette and Lighting: Deep shadows, candlelit interiors, cold moonlight contrasting with warm hearths, and an oppressive palette of midnight blues, blood reds, and sepia tones.
# ...

# %%
image_prompt
# Out:
# "Lucy, the lovingly secretive writer, sits alone in her dimly lit room, surrounded by ancient books and flickering candles. Her face is illuminated by the soft glow of the fireplace, casting an eerie shadow across the dusty wooden floor. As she writes with fervor, her delicate fingers dance across the pages, creating a symphony of ink and paper that echoes through the silent night. The atmosphere is hauntingly beautiful, filled with gothic dread and suspense, yet punctuated by moments of warmth and comfort. The colors are rich and vibrant, with deep blues and blood reds dominating the scene, contrasted by warm yellows and oranges that illuminate Lucy's passionate expression. The composition is carefully crafted, framing Lucy in the center of the canvas while subtly hinting at the mysterious forces lurking beyond the edges. The overall effect is a mesmerizing, otherworldly"
